# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.7/site-packages (4.5.5.64)
# Requirement already satisfied: numpy>=1.14.5 in /opt/conda/lib/python3.7/site-packages (from opencv-python) (1.19.5)

# %%
import os
import random

import cv2
import numpy as np

import torch
from torch.utils.data import DataLoader
from torchvision import models

from src.resnet_yolo import resnet50
from yolo_loss import YoloLoss
from src.dataset import VocDetectorDataset
from src.eval_voc import evaluate
from src.predict import predict_image
from src.config import VOC_CLASSES, COLORS
from kaggle_submission import output_submission_csv

import matplotlib.pyplot as plt
import collections

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Initialization

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# YOLO network hyperparameters
B = 2  # number of bounding box predictions per cell
S = 14  # width/height of network output grid (larger than 7x7 from paper since we use a different network)

# %% [markdown]
# To implement Yolo we will rely on a pretrained classifier as the backbone for our detection network. PyTorch offers a variety of models which are pretrained on ImageNet in the [`torchvision.models`](https://pytorch.org/docs/stable/torchvision/models.html) package. In particular, we will use the ResNet50 architecture as a base for our detector. This is different from the base architecture in the Yolo paper and also results in a different output grid size (14x14 instead of 7x7).
#
# Models are typically pretrained on ImageNet since the dataset is very large (> 1 million images) and widely used. The pretrained model provides a very useful weight initialization for our detector, so that the network is able to learn quickly and effectively.

# %%
load_network_path = 'checkpoints/best_detector.pth' 
pretrained = True

# use to load a previously trained network
if load_network_path is not None:
    print('Loading saved network from {}'.format(load_network_path))
    net = resnet50().to(device)
    net.load_state_dict(torch.load(load_network_path))
else:
    print('Load pre-trained model')
    net = resnet50(pretrained=pretrained).to(device)

# %%
learning_rate = 0.001
num_epochs = 50
batch_size = 24

# Yolo loss component coefficients (as given in Yolo v1 paper)
lambda_coord = 5
lambda_noobj = 0.5

# %% [markdown]
# ## Reading Pascal Data

# %% [markdown]
# Since Pascal is a small dataset (5000 in train+val) we have combined the train and val splits to train our detector. This is not typically a good practice, but we will make an exception in this case to be able to get reasonable detection results with a comparatively small object detection dataset.
#
# The train dataset loader also using a variety of data augmentation techniques including random shift, scaling, crop, and flips. Data augmentation is slightly more complicated for detection datasets since the bounding box annotations must be kept consistent throughout the transformations.
#
# Since the output of the detector network we train is an SxSx(B*5+C), we use an encoder to convert the original bounding box coordinates into relative grid bounding box coordinates corresponding to the expected output. We also use a decoder which allows us to convert the opposite direction into image coordinate bounding boxes.

# %%
file_root_train = 'data/VOCdevkit_2007/VOC2007/JPEGImages/'
annotation_file_train = 'data/voc2007.txt'

train_dataset = VocDetectorDataset(root_img_dir=file_root_train,dataset_file=annotation_file_train,train=True, S=S)
train_loader = DataLoader(train_dataset,batch_size=batch_size,shuffle=True,num_workers=2)
print('Loaded %d train images' % len(train_dataset))
# Out:
# Initializing dataset
# Loaded 5011 train images

# %%
file_root_test = 'data/VOCdevkit_2007/VOC2007test/JPEGImages/'
annotation_file_test = 'data/voc2007test.txt'

test_dataset = VocDetectorDataset(root_img_dir=file_root_test,dataset_file=annotation_file_test,train=False, S=S)
test_loader = DataLoader(test_dataset,batch_size=batch_size,shuffle=False,num_workers=2)
print('Loaded %d test images' % len(test_dataset))
# Out:
# Initializing dataset
# Loaded 4950 test images

# %%
data = train_dataset[0]

# %% [markdown]
# ## Set up training tools

# %%
criterion = YoloLoss(S, B, lambda_coord, lambda_noobj)
optimizer = torch.optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=5e-4)

# %% [markdown]
# ## Train detector

# %%
best_test_loss = np.inf
learning_rate = 1e-3
for epoch in range(num_epochs):
    net.train()
    
    # Update learning rate late in training
    if epoch == 30 or epoch == 40:
        learning_rate /= 10.0

    for param_group in optimizer.param_groups:
        param_group['lr'] = learning_rate
    
    print('\n\nStarting epoch %d / %d' % (epoch + 1, num_epochs))
    print('Learning Rate for this epoch: {}'.format(learning_rate))
    
    total_loss = collections.defaultdict(int)
    
    for i, data in enumerate(train_loader):
        data = (item.to(device) for item in data)
        images, target_boxes, target_cls, has_object_map = data
        pred = net(images)
        loss_dict = criterion(pred, target_boxes, target_cls, has_object_map)
        for key in loss_dict:
            total_loss[key] += loss_dict[key].item()
        
        optimizer.zero_grad()
        loss_dict['total_loss'].backward()
        optimizer.step()
        
        if (i+1) % 50 == 0:
            outstring = 'Epoch [%d/%d], Iter [%d/%d], Loss: ' % ((epoch+1, num_epochs, i+1, len(train_loader)))
            outstring += ', '.join( "%s=%.3f" % (key[:-5], val / (i+1)) for key, val in total_loss.items() )
            print(outstring)
    
    # evaluate the network on the test data
    if (epoch + 1) % 2 == 0:
        test_aps = evaluate(net, test_dataset_file=annotation_file_test, img_root=file_root_test)
        print(epoch, test_aps)
    with torch.no_grad():
        test_loss = 0.0
        net.eval()
        for i, data in enumerate(test_loader):
            data = (item.to(device) for item in data)
            images, target_boxes, target_cls, has_object_map = data
            
            pred = net(images)
            loss_dict = criterion(pred, target_boxes, target_cls, has_object_map)
            test_loss += loss_dict['total_loss'].item()
        test_loss /= len(test_loader)
    
    if best_test_loss > test_loss:
        best_test_loss = test_loss
        print('Updating best test loss: %.5f' % best_test_loss)
        torch.save(net.state_dict(),'checkpoints/best_detector.pth')
    
    if (epoch+1) in [5, 10, 20, 30, 40]:
        torch.save(net.state_dict(),'checkpoints/detector_epoch_%d.pth' % (epoch+1))

    torch.save(net.state_dict(),'checkpoints/detector.pth')
# Out:
# Starting epoch 1 / 50
# Learning Rate for this epoch: 0.001
# Epoch [1/50], Iter [50/209], Loss: total=20.282, reg=0.758, containing_obj=0.302, no_obj=12.558, cls=6.664
# Epoch [1/50], Iter [100/209], Loss: total=12.459, reg=0.597, containing_obj=0.403, no_obj=6.510, cls=4.949
# Epoch [1/50], Iter [150/209], Loss: total=9.522, reg=0.501, containing_obj=0.468, no_obj=4.447, cls=4.107
# Epoch [1/50], Iter [200/209], Loss: total=7.916, reg=0.448, containing_obj=0.501, no_obj=3.398, cls=3.569
# Updating best test loss: 2.81143
#
#
# Starting epoch 2 / 50
# Learning Rate for this epoch: 0.001
# Epoch [2/50], Iter [50/209], Loss: total=2.786, reg=0.256, containing_obj=0.647, no_obj=0.205, cls=1.678
# Epoch [2/50], Iter [100/209], Loss: total=2.726, reg=0.250, containing_obj=0.656, no_obj=0.191, cls=1.629
# Epoch [2/50], Iter [150/209], Loss: total=2.674, reg=0.242, containing_obj=0.674, no_obj=0.180, cls=1.578
# Epoch [2/50], Iter [200/209], Loss: total=2.626, reg=0.238, containing_obj=0.690, no_obj=0.171, cls=1.527
# Updating best test loss: 2.27077
#
#
# Starting epoch 3 / 50
# Learning Rate for this epoch: 0.001
# Epoch [3/50], Iter [50/209], Loss: total=2.184, reg=0.207, containing_obj=0.730, no_obj=0.131, cls=1.117
# Epoch [3/50], Iter [100/209], Loss: total=2.146, reg=0.199, containing_obj=0.737, no_obj=0.127, cls=1.083
# Epoch [3/50], Iter [150/209], Loss: total=2.127, reg=0.199, containing_obj=0.738, no_obj=0.123, cls=1.067
# Updating best test loss: 1.97654
#
#
# Starting epoch 4 / 50
# Learning Rate for this epoch: 0.001
# Epoch [4/50], Iter [50/209], Loss: total=2.000, reg=0.192, containing_obj=0.790, no_obj=0.107, cls=0.911
# Epoch [4/50], Iter [100/209], Loss: total=1.905, reg=0.183, containing_obj=0.764, no_obj=0.106, cls=0.852
# Epoch [4/50], Iter [150/209], Loss: total=1.892, reg=0.178, containing_obj=0.768, no_obj=0.106, cls=0.841
# Epoch [4/50], Iter [200/209], Loss: total=1.879, reg=0.179, containing_obj=0.768, no_obj=0.105, cls=0.827
# Updating best test loss: 1.79290
#
#
# Starting epoch 5 / 50
# Learning Rate for this epoch: 0.001
# Epoch [5/50], Iter [50/209], Loss: total=1.775, reg=0.171, containing_obj=0.750, no_obj=0.107, cls=0.747
# Epoch [5/50], Iter [100/209], Loss: total=1.750, reg=0.164, containing_obj=0.749, no_obj=0.107, cls=0.729
# Epoch [5/50], Iter [150/209], Loss: total=1.742, reg=0.167, containing_obj=0.750, no_obj=0.109, cls=0.716
# Epoch [5/50], Iter [200/209], Loss: total=1.727, reg=0.168, containing_obj=0.743, no_obj=0.111, cls=0.705
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████████| 4950/4950 [04:48<00:00, 17.17it/s]
# ---class aeroplane ap 0.0---
# ---class bicycle ap 0.16180225066579498---
# ---class bird ap 0.050254781324748504---
# ---class boat ap 0.005640050697084918---
# ---class bottle ap 0.008016038635536505---
# ---class bus ap 0.012718736662398634---
# ---class car ap 0.10883903387478934---
# ---class cat ap 0.015426612493651602---
# ---class chair ap 0.07147340774359068---
# ---class cow ap 0.01677266315825786---
# ---class diningtable ap 0.03730243061548283---
# ---class dog ap 0.009109499907045918---
# ---class horse ap 0.27726250536766983---
# ---class motorbike ap 0.03393650793650793---
# ---class person ap 0.19798578996096022---
# ---class pottedplant ap 0.020896391861393644---
# ---class sheep ap 0.026914110454892993---
# ---class sofa ap 0.09791313451718792---
# ---class train ap 0.0--- (no predictions for this class)
# ---class tvmonitor ap 0.0214736553908757---
# ---map 0.058686880063393496---
# 4 [0.0, 0.16180225066579498, 0.050254781324748504, 0.005640050697084918, 0.008016038635536505, 0.012718736662398634, 0.10883903387478934, 0.015426612493651602, 0.07147340774359068, 0.01677266315825786, 0.03730243061548283, 0.009109499907045918, 0.27726250536766983, 0.03393650793650793, 0.19798578996096022, 0.020896391861393644, 0.026914110454892993, 0.09791313451718792, 0.0, 0.0214736553908757]
# Updating best test loss: 1.69706
#
#
# Starting epoch 6 / 50
# Learning Rate for this epoch: 0.001
# Epoch [6/50], Iter [50/209], Loss: total=1.571, reg=0.154, containing_obj=0.714, no_obj=0.114, cls=0.589
# Epoch [6/50], Iter [100/209], Loss: total=1.578, reg=0.155, containing_obj=0.719, no_obj=0.116, cls=0.588
# Epoch [6/50], Iter [150/209], Loss: total=1.588, reg=0.157, containing_obj=0.720, no_obj=0.118, cls=0.593
# Epoch [6/50], Iter [200/209], Loss: total=1.590, reg=0.157, containing_obj=0.720, no_obj=0.119, cls=0.594
#
#
# Starting epoch 7 / 50
# Learning Rate for this epoch: 0.001
# Epoch [7/50], Iter [50/209], Loss: total=1.605, reg=0.151, containing_obj=0.743, no_obj=0.121, cls=0.590
# Epoch [7/50], Iter [100/209], Loss: total=1.569, reg=0.152, containing_obj=0.730, no_obj=0.119, cls=0.568
# Epoch [7/50], Iter [150/209], Loss: total=1.540, reg=0.150, containing_obj=0.723, no_obj=0.121, cls=0.546
# Epoch [7/50], Iter [200/209], Loss: total=1.543, reg=0.150, containing_obj=0.722, no_obj=0.121, cls=0.549
# Updating best test loss: 1.59784
#
#
# Starting epoch 8 / 50
# Learning Rate for this epoch: 0.001
# Epoch [8/50], Iter [50/209], Loss: total=1.458, reg=0.150, containing_obj=0.706, no_obj=0.124, cls=0.478
# Epoch [8/50], Iter [100/209], Loss: total=1.483, reg=0.149, containing_obj=0.715, no_obj=0.122, cls=0.496
# Epoch [8/50], Iter [150/209], Loss: total=1.456, reg=0.148, containing_obj=0.707, no_obj=0.123, cls=0.478
# Epoch [8/50], Iter [200/209], Loss: total=1.448, reg=0.145, containing_obj=0.705, no_obj=0.123, cls=0.475
# Updating best test loss: 1.52134
#
#
# Starting epoch 9 / 50
# Learning Rate for this epoch: 0.001
# Epoch [9/50], Iter [50/209], Loss: total=1.378, reg=0.135, containing_obj=0.713, no_obj=0.122, cls=0.408
# Epoch [9/50], Iter [100/209], Loss: total=1.400, reg=0.138, containing_obj=0.710, no_obj=0.124, cls=0.427
# Epoch [9/50], Iter [150/209], Loss: total=1.408, reg=0.137, containing_obj=0.712, no_obj=0.124, cls=0.436
# Epoch [9/50], Iter [200/209], Loss: total=1.397, reg=0.136, containing_obj=0.707, no_obj=0.123, cls=0.431
#
#
# Starting epoch 10 / 50
# Learning Rate for this epoch: 0.001
# Epoch [10/50], Iter [50/209], Loss: total=1.423, reg=0.140, containing_obj=0.728, no_obj=0.127, cls=0.427
# Epoch [10/50], Iter [100/209], Loss: total=1.379, reg=0.133, containing_obj=0.716, no_obj=0.127, cls=0.402
# Epoch [10/50], Iter [150/209], Loss: total=1.362, reg=0.132, containing_obj=0.705, no_obj=0.128, cls=0.397
# Epoch [10/50], Iter [200/209], Loss: total=1.349, reg=0.131, containing_obj=0.697, no_obj=0.129, cls=0.392
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████████| 4950/4950 [04:48<00:00, 17.17it/s]
# ---class aeroplane ap 0.02034551176364576---
# ---class bicycle ap 0.2537945477997502---
# ---class bird ap 0.28615524238100853---
# ---class boat ap 0.030357937526723017---
# ---class bottle ap 0.0631265097720026---
# ---class bus ap 0.13176574503957636---
# ---class car ap 0.27833745812601074---
# ---class cat ap 0.4610159026823607---
# ---class chair ap 0.19049415617023951---
# ---class cow ap 0.25777506527948113---
# ---class diningtable ap 0.1235939495379418---
# ---class dog ap 0.45396159693159005---
# ---class horse ap 0.5053660947865947---
# ---class motorbike ap 0.3698853549069565---
# ---class person ap 0.37568783374726605---
# ---class pottedplant ap 0.10161283548028699---
# ---class sheep ap 0.1486620344400786---
# ---class sofa ap 0.3143377689233451---
# ---class train ap 0.06266422519888495---
# ---class tvmonitor ap 0.3413305919028129---
# ---map 0.23851351811982782---
# 9 [0.02034551176364576, 0.2537945477997502, 0.28615524238100853, 0.030357937526723017, 0.0631265097720026, 0.13176574503957636, 0.27833745812601074, 0.4610159026823607, 0.19049415617023951, 0.25777506527948113, 0.1235939495379418, 0.45396159693159005, 0.5053660947865947, 0.3698853549069565, 0.37568783374726605, 0.10161283548028699, 0.1486620344400786, 0.3143377689233451, 0.06266422519888495, 0.3413305919028129]
# Updating best test loss: 1.46648
#
#
# Starting epoch 11 / 50
# Learning Rate for this epoch: 0.001
# Epoch [11/50], Iter [50/209], Loss: total=1.301, reg=0.127, containing_obj=0.692, no_obj=0.131, cls=0.351
# Epoch [11/50], Iter [100/209], Loss: total=1.308, reg=0.126, containing_obj=0.693, no_obj=0.130, cls=0.360
# Epoch [11/50], Iter [150/209], Loss: total=1.308, reg=0.128, containing_obj=0.693, no_obj=0.130, cls=0.357
# Epoch [11/50], Iter [200/209], Loss: total=1.314, reg=0.127, containing_obj=0.693, no_obj=0.131, cls=0.363
#
#
# Starting epoch 12 / 50
# Learning Rate for this epoch: 0.001
# Epoch [12/50], Iter [50/209], Loss: total=1.262, reg=0.125, containing_obj=0.682, no_obj=0.133, cls=0.322
# Epoch [12/50], Iter [100/209], Loss: total=1.264, reg=0.123, containing_obj=0.678, no_obj=0.131, cls=0.332
# Epoch [12/50], Iter [150/209], Loss: total=1.286, reg=0.125, containing_obj=0.691, no_obj=0.130, cls=0.340
# Epoch [12/50], Iter [200/209], Loss: total=1.289, reg=0.125, containing_obj=0.690, no_obj=0.131, cls=0.343
# Updating best test loss: 1.46021
#
#
# Starting epoch 13 / 50
# Learning Rate for this epoch: 0.001
# Epoch [13/50], Iter [50/209], Loss: total=1.263, reg=0.116, containing_obj=0.700, no_obj=0.130, cls=0.317
# Epoch [13/50], Iter [100/209], Loss: total=1.246, reg=0.117, containing_obj=0.697, no_obj=0.133, cls=0.299
# Epoch [13/50], Iter [150/209], Loss: total=1.235, reg=0.119, containing_obj=0.689, no_obj=0.132, cls=0.294
# Epoch [13/50], Iter [200/209], Loss: total=1.240, reg=0.119, containing_obj=0.685, no_obj=0.132, cls=0.304
# Updating best test loss: 1.45433
#
#
# Starting epoch 14 / 50
# Learning Rate for this epoch: 0.001
# Epoch [14/50], Iter [50/209], Loss: total=1.231, reg=0.119, containing_obj=0.681, no_obj=0.133, cls=0.297
# Epoch [14/50], Iter [100/209], Loss: total=1.210, reg=0.115, containing_obj=0.670, no_obj=0.134, cls=0.291
# Epoch [14/50], Iter [150/209], Loss: total=1.222, reg=0.115, containing_obj=0.677, no_obj=0.133, cls=0.296
# Epoch [14/50], Iter [200/209], Loss: total=1.233, reg=0.116, containing_obj=0.684, no_obj=0.133, cls=0.300
# Updating best test loss: 1.45089
#
#
# Starting epoch 15 / 50
# Learning Rate for this epoch: 0.001
# Epoch [15/50], Iter [50/209], Loss: total=1.218, reg=0.117, containing_obj=0.681, no_obj=0.138, cls=0.282
# Epoch [15/50], Iter [100/209], Loss: total=1.177, reg=0.114, containing_obj=0.660, no_obj=0.137, cls=0.267
# Epoch [15/50], Iter [150/209], Loss: total=1.168, reg=0.111, containing_obj=0.654, no_obj=0.139, cls=0.264
# Epoch [15/50], Iter [200/209], Loss: total=1.175, reg=0.112, containing_obj=0.659, no_obj=0.139, cls=0.265
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████████| 4950/4950 [04:51<00:00, 16.99it/s]
# ---class aeroplane ap 0.216875352916388---
# ---class bicycle ap 0.3805439520385306---
# ---class bird ap 0.29678468290809723---
# ---class boat ap 0.07215253193225421---
# ---class bottle ap 0.10772409907055841---
# ---class bus ap 0.2712860760140248---
# ---class car ap 0.4297386545524269---
# ---class cat ap 0.48755496380264673---
# ---class chair ap 0.23776192698728907---
# ---class cow ap 0.31846693237577894---
# ---class diningtable ap 0.2708074179350716---
# ---class dog ap 0.5290188336610566---
# ---class horse ap 0.5372246140845858---
# ---class motorbike ap 0.40454593382644294---
# ---class person ap 0.4396565086355186---
# ---class pottedplant ap 0.1023262797799851---
# ---class sheep ap 0.2509048449120873---
# ---class sofa ap 0.4003952932562719---
# ---class train ap 0.2704075653889449---
# ---class tvmonitor ap 0.33577047370891816---
# ---map 0.3179973468893439---
# 14 [0.216875352916388, 0.3805439520385306, 0.29678468290809723, 0.07215253193225421, 0.10772409907055841, 0.2712860760140248, 0.4297386545524269, 0.48755496380264673, 0.23776192698728907, 0.31846693237577894, 0.2708074179350716, 0.5290188336610566, 0.5372246140845858, 0.40454593382644294, 0.4396565086355186, 0.1023262797799851, 0.2509048449120873, 0.4003952932562719, 0.2704075653889449, 0.33577047370891816]
#
#
# Starting epoch 16 / 50
# Learning Rate for this epoch: 0.001
# Epoch [16/50], Iter [50/209], Loss: total=1.118, reg=0.107, containing_obj=0.648, no_obj=0.139, cls=0.224
# Epoch [16/50], Iter [100/209], Loss: total=1.174, reg=0.110, containing_obj=0.662, no_obj=0.139, cls=0.263
# Epoch [16/50], Iter [150/209], Loss: total=1.173, reg=0.111, containing_obj=0.667, no_obj=0.140, cls=0.256
# Epoch [16/50], Iter [200/209], Loss: total=1.173, reg=0.112, containing_obj=0.668, no_obj=0.140, cls=0.255
# Updating best test loss: 1.40493
#
#
# Starting epoch 17 / 50
# Learning Rate for this epoch: 0.001
# Epoch [17/50], Iter [50/209], Loss: total=1.151, reg=0.105, containing_obj=0.678, no_obj=0.135, cls=0.233
# Epoch [17/50], Iter [100/209], Loss: total=1.160, reg=0.105, containing_obj=0.679, no_obj=0.136, cls=0.240
# Epoch [17/50], Iter [150/209], Loss: total=1.159, reg=0.105, containing_obj=0.674, no_obj=0.139, cls=0.241
# Epoch [17/50], Iter [200/209], Loss: total=1.160, reg=0.106, containing_obj=0.674, no_obj=0.140, cls=0.241
#
#
# Starting epoch 18 / 50
# Learning Rate for this epoch: 0.001
# Epoch [18/50], Iter [50/209], Loss: total=1.136, reg=0.109, containing_obj=0.665, no_obj=0.143, cls=0.218
# Epoch [18/50], Iter [100/209], Loss: total=1.122, reg=0.106, containing_obj=0.646, no_obj=0.144, cls=0.225
# Epoch [18/50], Iter [150/209], Loss: total=1.130, reg=0.105, containing_obj=0.646, no_obj=0.145, cls=0.234
# Epoch [18/50], Iter [200/209], Loss: total=1.145, reg=0.106, containing_obj=0.658, no_obj=0.144, cls=0.237
#
#
# Starting epoch 19 / 50
# Learning Rate for this epoch: 0.001
# Epoch [19/50], Iter [50/209], Loss: total=1.169, reg=0.106, containing_obj=0.675, no_obj=0.149, cls=0.239
# Epoch [19/50], Iter [100/209], Loss: total=1.148, reg=0.104, containing_obj=0.665, no_obj=0.146, cls=0.232
# Epoch [19/50], Iter [150/209], Loss: total=1.128, reg=0.102, containing_obj=0.653, no_obj=0.147, cls=0.227
# Epoch [19/50], Iter [200/209], Loss: total=1.127, reg=0.101, containing_obj=0.655, no_obj=0.147, cls=0.224
#
#
# Starting epoch 20 / 50
# Learning Rate for this epoch: 0.001
# Epoch [20/50], Iter [50/209], Loss: total=1.072, reg=0.098, containing_obj=0.634, no_obj=0.145, cls=0.196
# Epoch [20/50], Iter [100/209], Loss: total=1.100, reg=0.100, containing_obj=0.647, no_obj=0.147, cls=0.205
# Epoch [20/50], Iter [150/209], Loss: total=1.101, reg=0.101, containing_obj=0.647, no_obj=0.148, cls=0.206
# Epoch [20/50], Iter [200/209], Loss: total=1.098, reg=0.099, containing_obj=0.648, no_obj=0.147, cls=0.204
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████████| 4950/4950 [04:49<00:00, 17.12it/s]
# ---class aeroplane ap 0.3062029957592992---
# ---class bicycle ap 0.39716456528748023---
# ---class bird ap 0.37797558505676165---
# ---class boat ap 0.11283306535865682---
# ---class bottle ap 0.1308951932896614---
# ---class bus ap 0.2687620898846682---
# ---class car ap 0.477317671965637---
# ---class cat ap 0.6007814817047246---
# ---class chair ap 0.27340198028649---
# ---class cow ap 0.385893303663876---
# ---class diningtable ap 0.23042511111791833---
# ---class dog ap 0.516259952336187---
# ---class horse ap 0.5769494811203189---
# ---class motorbike ap 0.450215729544065---
# ---class person ap 0.46571790056167994---
# ---class pottedplant ap 0.11625893081245825---
# ---class sheep ap 0.254914706733981---
# ---class sofa ap 0.32580166521457277---
# ---class train ap 0.3689891366080237---
# ---class tvmonitor ap 0.39946622367988005---
# ---map 0.351811338499317---
# 19 [0.3062029957592992, 0.39716456528748023, 0.37797558505676165, 0.11283306535865682, 0.1308951932896614, 0.2687620898846682, 0.477317671965637, 0.6007814817047246, 0.27340198028649, 0.385893303663876, 0.23042511111791833, 0.516259952336187, 0.5769494811203189, 0.450215729544065, 0.46571790056167994, 0.11625893081245825, 0.254914706733981, 0.32580166521457277, 0.3689891366080237, 0.39946622367988005]
#
#
# Starting epoch 21 / 50
# Learning Rate for this epoch: 0.001
# Epoch [21/50], Iter [50/209], Loss: total=1.053, reg=0.096, containing_obj=0.633, no_obj=0.148, cls=0.177
# Epoch [21/50], Iter [100/209], Loss: total=1.076, reg=0.097, containing_obj=0.637, no_obj=0.150, cls=0.192
# Epoch [21/50], Iter [200/209], Loss: total=1.084, reg=0.096, containing_obj=0.641, no_obj=0.150, cls=0.198
#
#
# Starting epoch 22 / 50
# Learning Rate for this epoch: 0.001
# Epoch [22/50], Iter [50/209], Loss: total=1.113, reg=0.096, containing_obj=0.670, no_obj=0.153, cls=0.194
# Epoch [22/50], Iter [100/209], Loss: total=1.091, reg=0.094, containing_obj=0.648, no_obj=0.155, cls=0.194
# Epoch [22/50], Iter [150/209], Loss: total=1.093, reg=0.098, containing_obj=0.650, no_obj=0.153, cls=0.192
# Epoch [22/50], Iter [200/209], Loss: total=1.080, reg=0.097, containing_obj=0.642, no_obj=0.152, cls=0.189
#
#
# Starting epoch 23 / 50
# Learning Rate for this epoch: 0.001
# Epoch [23/50], Iter [50/209], Loss: total=1.032, reg=0.090, containing_obj=0.621, no_obj=0.148, cls=0.172
# Epoch [23/50], Iter [100/209], Loss: total=1.053, reg=0.092, containing_obj=0.635, no_obj=0.150, cls=0.176
# Epoch [23/50], Iter [150/209], Loss: total=1.069, reg=0.095, containing_obj=0.638, no_obj=0.151, cls=0.186
# Epoch [23/50], Iter [200/209], Loss: total=1.072, reg=0.095, containing_obj=0.639, no_obj=0.150, cls=0.187
#
#
# Starting epoch 24 / 50
# Learning Rate for this epoch: 0.001
# Epoch [24/50], Iter [50/209], Loss: total=1.059, reg=0.093, containing_obj=0.632, no_obj=0.152, cls=0.181
# Epoch [24/50], Iter [100/209], Loss: total=1.045, reg=0.094, containing_obj=0.622, no_obj=0.155, cls=0.174
# Epoch [24/50], Iter [150/209], Loss: total=1.057, reg=0.094, containing_obj=0.629, no_obj=0.154, cls=0.180
# Epoch [24/50], Iter [200/209], Loss: total=1.059, reg=0.094, containing_obj=0.627, no_obj=0.155, cls=0.183
#
#
# Starting epoch 25 / 50
# Learning Rate for this epoch: 0.001
# Epoch [25/50], Iter [50/209], Loss: total=1.056, reg=0.092, containing_obj=0.631, no_obj=0.152, cls=0.181
# Epoch [25/50], Iter [100/209], Loss: total=1.049, reg=0.090, containing_obj=0.630, no_obj=0.154, cls=0.175
# Epoch [25/50], Iter [150/209], Loss: total=1.025, reg=0.090, containing_obj=0.616, no_obj=0.155, cls=0.164
# Epoch [25/50], Iter [200/209], Loss: total=1.032, reg=0.091, containing_obj=0.617, no_obj=0.155, cls=0.169
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████████| 4950/4950 [04:50<00:00, 17.03it/s]
# ---class aeroplane ap 0.3423936349683237---
# ---class bicycle ap 0.46661852375538776---
# ---class bird ap 0.3892442909087511---
# ---class boat ap 0.12549682126394052---
# ---class bottle ap 0.14377078387140818---
# ---class bus ap 0.39917584114032173---
# ---class car ap 0.5267707765871412---
# ---class cat ap 0.6304396503986563---
# ---class chair ap 0.2705436141270141---
# ---class cow ap 0.3928064563060163---
# ---class diningtable ap 0.24561833414441972---
# ---class dog ap 0.5905668104353661---
# ---class horse ap 0.6302119059996056---
# ---class motorbike ap 0.5083191997204166---
# ---class person ap 0.48262776200624297---
# ---class pottedplant ap 0.1134428845297849---
# ---class sheep ap 0.2806737988029109---
# ---class sofa ap 0.4242059772412718---
# ---class train ap 0.4542725760850599---
# ---class tvmonitor ap 0.40001253868297365---
# ---map 0.39086060904875064---
# 24 [0.3423936349683237, 0.46661852375538776, 0.3892442909087511, 0.12549682126394052, 0.14377078387140818, 0.39917584114032173, 0.5267707765871412, 0.6304396503986563, 0.2705436141270141, 0.3928064563060163, 0.24561833414441972, 0.5905668104353661, 0.6302119059996056, 0.5083191997204166, 0.48262776200624297, 0.1134428845297849, 0.2806737988029109, 0.4242059772412718, 0.4542725760850599, 0.40001253868297365]
# Updating best test loss: 1.38729
#
#
# Starting epoch 26 / 50
# Learning Rate for this epoch: 0.001
# Epoch [26/50], Iter [50/209], Loss: total=1.029, reg=0.089, containing_obj=0.619, no_obj=0.155, cls=0.166
# Epoch [26/50], Iter [100/209], Loss: total=1.028, reg=0.089, containing_obj=0.620, no_obj=0.155, cls=0.164
# Epoch [26/50], Iter [200/209], Loss: total=1.032, reg=0.091, containing_obj=0.621, no_obj=0.155, cls=0.166
#
#
# Starting epoch 27 / 50
# Learning Rate for this epoch: 0.001
# Epoch [27/50], Iter [50/209], Loss: total=1.004, reg=0.085, containing_obj=0.604, no_obj=0.155, cls=0.160
# Epoch [27/50], Iter [100/209], Loss: total=1.021, reg=0.090, containing_obj=0.608, no_obj=0.158, cls=0.165
# Epoch [27/50], Iter [150/209], Loss: total=1.011, reg=0.089, containing_obj=0.601, no_obj=0.159, cls=0.163
# Epoch [27/50], Iter [200/209], Loss: total=1.021, reg=0.090, containing_obj=0.608, no_obj=0.157, cls=0.166
#
#
# Starting epoch 28 / 50
# Learning Rate for this epoch: 0.001
# Epoch [28/50], Iter [50/209], Loss: total=1.039, reg=0.093, containing_obj=0.615, no_obj=0.159, cls=0.173
# Epoch [28/50], Iter [100/209], Loss: total=1.025, reg=0.089, containing_obj=0.615, no_obj=0.158, cls=0.162
# Epoch [28/50], Iter [150/209], Loss: total=1.023, reg=0.088, containing_obj=0.615, no_obj=0.157, cls=0.163
# Epoch [28/50], Iter [200/209], Loss: total=1.014, reg=0.086, containing_obj=0.611, no_obj=0.158, cls=0.159
#
#
# Starting epoch 29 / 50
# Learning Rate for this epoch: 0.001
# Epoch [29/50], Iter [50/209], Loss: total=0.991, reg=0.081, containing_obj=0.598, no_obj=0.168, cls=0.144
# Epoch [29/50], Iter [100/209], Loss: total=1.002, reg=0.083, containing_obj=0.604, no_obj=0.164, cls=0.152
# Epoch [29/50], Iter [150/209], Loss: total=1.013, reg=0.085, containing_obj=0.610, no_obj=0.162, cls=0.156
# Epoch [29/50], Iter [200/209], Loss: total=1.004, reg=0.085, containing_obj=0.605, no_obj=0.162, cls=0.153
#
#
# Starting epoch 30 / 50
# Learning Rate for this epoch: 0.001
# Epoch [30/50], Iter [50/209], Loss: total=1.021, reg=0.086, containing_obj=0.614, no_obj=0.163, cls=0.159
# Epoch [30/50], Iter [100/209], Loss: total=1.021, reg=0.086, containing_obj=0.612, no_obj=0.161, cls=0.162
# Epoch [30/50], Iter [150/209], Loss: total=1.007, reg=0.087, containing_obj=0.603, no_obj=0.162, cls=0.155
# Epoch [30/50], Iter [200/209], Loss: total=1.004, reg=0.086, containing_obj=0.599, no_obj=0.162, cls=0.157
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████████| 4950/4950 [04:54<00:00, 16.83it/s]
# ---class aeroplane ap 0.41081837479607797---
# ---class bicycle ap 0.4952555308883966---
# ---class bird ap 0.4281897964855462---
# ---class boat ap 0.20472913793003344---
# ---class bottle ap 0.13838697274549297---
# ---class bus ap 0.5047330910591759---
# ---class car ap 0.5439554854245512---
# ---class cat ap 0.6831445362405061---
# ---class chair ap 0.27662787708820874---
# ---class cow ap 0.43327686676887367---
# ---class diningtable ap 0.2756582090413899---
# ---class dog ap 0.6268932789174302---
# ---class horse ap 0.6250985365007871---
# ---class motorbike ap 0.4415468437746345---
# ---class person ap 0.4809767904621072---
# ---class pottedplant ap 0.13256070943059306---
# ---class sheep ap 0.3927425636711426---
# ---class sofa ap 0.4176253696555413---
# ---class train ap 0.4607593972108821---
# ---class tvmonitor ap 0.42781575784482406---
# ---map 0.4200397562968098---
# 29 [0.41081837479607797, 0.4952555308883966, 0.4281897964855462, 0.20472913793003344, 0.13838697274549297, 0.5047330910591759, 0.5439554854245512, 0.6831445362405061, 0.27662787708820874, 0.43327686676887367, 0.2756582090413899, 0.6268932789174302, 0.6250985365007871, 0.4415468437746345, 0.4809767904621072, 0.13256070943059306, 0.3927425636711426, 0.4176253696555413, 0.4607593972108821, 0.42781575784482406]
#
#
# Starting epoch 31 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [31/50], Iter [50/209], Loss: total=0.980, reg=0.086, containing_obj=0.605, no_obj=0.153, cls=0.135
# Epoch [31/50], Iter [100/209], Loss: total=0.978, reg=0.085, containing_obj=0.597, no_obj=0.156, cls=0.140
# Epoch [31/50], Iter [150/209], Loss: total=0.984, reg=0.084, containing_obj=0.602, no_obj=0.158, cls=0.140
# Epoch [31/50], Iter [200/209], Loss: total=0.975, reg=0.083, containing_obj=0.593, no_obj=0.160, cls=0.139
# Updating best test loss: 1.36438
#
#
# Starting epoch 32 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [32/50], Iter [50/209], Loss: total=0.966, reg=0.087, containing_obj=0.594, no_obj=0.161, cls=0.124
# Epoch [32/50], Iter [100/209], Loss: total=0.963, reg=0.086, containing_obj=0.580, no_obj=0.163, cls=0.134
# Epoch [32/50], Iter [150/209], Loss: total=0.965, reg=0.084, containing_obj=0.584, no_obj=0.162, cls=0.135
# Epoch [32/50], Iter [200/209], Loss: total=0.959, reg=0.083, containing_obj=0.582, no_obj=0.162, cls=0.132
#
#
# Starting epoch 33 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [33/50], Iter [50/209], Loss: total=0.967, reg=0.084, containing_obj=0.585, no_obj=0.161, cls=0.136
# Epoch [33/50], Iter [100/209], Loss: total=0.949, reg=0.079, containing_obj=0.577, no_obj=0.164, cls=0.129
# Epoch [33/50], Iter [150/209], Loss: total=0.943, reg=0.079, containing_obj=0.572, no_obj=0.166, cls=0.126
# Epoch [33/50], Iter [200/209], Loss: total=0.949, reg=0.080, containing_obj=0.575, no_obj=0.165, cls=0.129
# Updating best test loss: 1.36128
#
#
# Starting epoch 34 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [34/50], Iter [50/209], Loss: total=0.979, reg=0.082, containing_obj=0.610, no_obj=0.163, cls=0.124
# Epoch [34/50], Iter [100/209], Loss: total=0.962, reg=0.084, containing_obj=0.587, no_obj=0.164, cls=0.126
# Epoch [34/50], Iter [150/209], Loss: total=0.948, reg=0.083, containing_obj=0.572, no_obj=0.166, cls=0.128
# Epoch [34/50], Iter [200/209], Loss: total=0.947, reg=0.082, containing_obj=0.571, no_obj=0.167, cls=0.127
#
#
# Starting epoch 35 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [35/50], Iter [50/209], Loss: total=0.937, reg=0.080, containing_obj=0.564, no_obj=0.165, cls=0.128
# Epoch [35/50], Iter [100/209], Loss: total=0.953, reg=0.079, containing_obj=0.585, no_obj=0.164, cls=0.125
# Epoch [35/50], Iter [150/209], Loss: total=0.954, reg=0.080, containing_obj=0.584, no_obj=0.165, cls=0.125
# Epoch [35/50], Iter [200/209], Loss: total=0.955, reg=0.080, containing_obj=0.586, no_obj=0.166, cls=0.123
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████████| 4950/4950 [04:52<00:00, 16.94it/s]
# ---class aeroplane ap 0.40689498434996213---
# ---class bicycle ap 0.5058468618202662---
# ---class bird ap 0.39348829957770354---
# ---class boat ap 0.19673749499045934---
# ---class bottle ap 0.14968494493464318---
# ---class bus ap 0.5329337406131149---
# ---class car ap 0.5585720088965459---
# ---class cat ap 0.665062291592666---
# ---class chair ap 0.2895871210013118---
# ---class cow ap 0.46112237103977427---
# ---class diningtable ap 0.3032119583259736---
# ---class dog ap 0.6146089554193378---
# ---class horse ap 0.6190622700721521---
# ---class motorbike ap 0.4977766918303205---
# ---class person ap 0.47799714532382365---
# ---class pottedplant ap 0.14708503965889946---
# ---class sheep ap 0.36779702466516995---
# ---class sofa ap 0.416875077885918---
# ---class train ap 0.522114990541861---
# ---class tvmonitor ap 0.408383563361045---
# ---map 0.4267421417950474---
# 34 [0.40689498434996213, 0.5058468618202662, 0.39348829957770354, 0.19673749499045934, 0.14968494493464318, 0.5329337406131149, 0.5585720088965459, 0.665062291592666, 0.2895871210013118, 0.46112237103977427, 0.3032119583259736, 0.6146089554193378, 0.6190622700721521, 0.4977766918303205, 0.47799714532382365, 0.14708503965889946, 0.36779702466516995, 0.416875077885918, 0.522114990541861, 0.408383563361045]
# Updating best test loss: 1.34667
#
#
# Starting epoch 36 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [36/50], Iter [50/209], Loss: total=0.897, reg=0.079, containing_obj=0.541, no_obj=0.166, cls=0.111
# Epoch [36/50], Iter [100/209], Loss: total=0.920, reg=0.080, containing_obj=0.561, no_obj=0.165, cls=0.115
# Epoch [36/50], Iter [150/209], Loss: total=0.940, reg=0.081, containing_obj=0.573, no_obj=0.164, cls=0.122
# Epoch [36/50], Iter [200/209], Loss: total=0.936, reg=0.080, containing_obj=0.569, no_obj=0.165, cls=0.122
#
#
# Starting epoch 37 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [37/50], Iter [50/209], Loss: total=0.969, reg=0.081, containing_obj=0.591, no_obj=0.170, cls=0.127
# Epoch [37/50], Iter [100/209], Loss: total=0.925, reg=0.077, containing_obj=0.570, no_obj=0.169, cls=0.108
# Epoch [37/50], Iter [150/209], Loss: total=0.937, reg=0.079, containing_obj=0.575, no_obj=0.169, cls=0.113
# Epoch [37/50], Iter [200/209], Loss: total=0.928, reg=0.078, containing_obj=0.568, no_obj=0.169, cls=0.112
#
#
# Starting epoch 38 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [38/50], Iter [50/209], Loss: total=0.934, reg=0.082, containing_obj=0.566, no_obj=0.170, cls=0.116
# Epoch [38/50], Iter [100/209], Loss: total=0.956, reg=0.081, containing_obj=0.579, no_obj=0.171, cls=0.124
# Epoch [38/50], Iter [150/209], Loss: total=0.947, reg=0.079, containing_obj=0.576, no_obj=0.170, cls=0.121
# Epoch [38/50], Iter [200/209], Loss: total=0.936, reg=0.079, containing_obj=0.570, no_obj=0.169, cls=0.118
#
#
# Starting epoch 39 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [39/50], Iter [50/209], Loss: total=0.959, reg=0.080, containing_obj=0.584, no_obj=0.166, cls=0.129
# Epoch [39/50], Iter [100/209], Loss: total=0.968, reg=0.080, containing_obj=0.597, no_obj=0.166, cls=0.125
# Epoch [39/50], Iter [150/209], Loss: total=0.961, reg=0.081, containing_obj=0.585, no_obj=0.168, cls=0.127
# Epoch [39/50], Iter [200/209], Loss: total=0.945, reg=0.080, containing_obj=0.575, no_obj=0.168, cls=0.122
#
#
# Starting epoch 40 / 50
# Learning Rate for this epoch: 0.0001
# Epoch [40/50], Iter [50/209], Loss: total=0.941, reg=0.079, containing_obj=0.579, no_obj=0.162, cls=0.120
# Epoch [40/50], Iter [100/209], Loss: total=0.935, reg=0.078, containing_obj=0.577, no_obj=0.165, cls=0.114
# Epoch [40/50], Iter [150/209], Loss: total=0.922, reg=0.077, containing_obj=0.569, no_obj=0.164, cls=0.111
# Epoch [40/50], Iter [200/209], Loss: total=0.924, reg=0.078, containing_obj=0.569, no_obj=0.165, cls=0.112
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████████| 4950/4950 [04:51<00:00, 16.99it/s]
# ---class aeroplane ap 0.39392219812925344---
# ---class bicycle ap 0.5304450455435932---
# ---class bird ap 0.4240434990620282---
# ---class boat ap 0.2069551929410681---
# ---class bottle ap 0.16418624635233597---
# ---class bus ap 0.5370936198645698---
# ---class car ap 0.5798126911149538---
# ---class cat ap 0.6762609385078249---
# ---class chair ap 0.2787603057040069---
# ---class cow ap 0.45807662508969693---
# ---class diningtable ap 0.2727564320761733---
# ---class dog ap 0.6566636668092489---
# ---class horse ap 0.6308957299729849---
# ---class motorbike ap 0.509241848567119---
# ---class person ap 0.5115735711406362---
# ---class pottedplant ap 0.15641108616519295---
# ---class sheep ap 0.40323737138313454---
# ---class sofa ap 0.3912679711541377---
# ---class train ap 0.5359649300269763---
# ---class tvmonitor ap 0.42513424435246494---
# ---map 0.43713516069787---
# 39 [0.39392219812925344, 0.5304450455435932, 0.4240434990620282, 0.2069551929410681, 0.16418624635233597, 0.5370936198645698, 0.5798126911149538, 0.6762609385078249, 0.2787603057040069, 0.45807662508969693, 0.2727564320761733, 0.6566636668092489, 0.6308957299729849, 0.509241848567119, 0.5115735711406362, 0.15641108616519295, 0.40323737138313454, 0.3912679711541377, 0.5359649300269763, 0.42513424435246494]
#
#
# Starting epoch 41 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [41/50], Iter [50/209], Loss: total=0.896, reg=0.079, containing_obj=0.547, no_obj=0.170, cls=0.101
# Epoch [41/50], Iter [100/209], Loss: total=0.918, reg=0.078, containing_obj=0.567, no_obj=0.168, cls=0.105
# Epoch [41/50], Iter [150/209], Loss: total=0.923, reg=0.079, containing_obj=0.565, no_obj=0.167, cls=0.111
# Epoch [41/50], Iter [200/209], Loss: total=0.929, reg=0.079, containing_obj=0.570, no_obj=0.167, cls=0.113
#
#
# Starting epoch 42 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [42/50], Iter [50/209], Loss: total=0.954, reg=0.080, containing_obj=0.590, no_obj=0.166, cls=0.119
# Epoch [42/50], Iter [100/209], Loss: total=0.922, reg=0.076, containing_obj=0.566, no_obj=0.168, cls=0.112
# Epoch [42/50], Iter [150/209], Loss: total=0.924, reg=0.077, containing_obj=0.565, no_obj=0.167, cls=0.115
# Epoch [42/50], Iter [200/209], Loss: total=0.924, reg=0.078, containing_obj=0.563, no_obj=0.167, cls=0.116
#
#
# Starting epoch 43 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [43/50], Iter [50/209], Loss: total=0.891, reg=0.076, containing_obj=0.547, no_obj=0.169, cls=0.099
# Epoch [43/50], Iter [100/209], Loss: total=0.906, reg=0.075, containing_obj=0.552, no_obj=0.167, cls=0.112
# Epoch [43/50], Iter [150/209], Loss: total=0.914, reg=0.076, containing_obj=0.561, no_obj=0.166, cls=0.110
# Epoch [43/50], Iter [200/209], Loss: total=0.920, reg=0.077, containing_obj=0.565, no_obj=0.166, cls=0.113
#
#
# Starting epoch 44 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [44/50], Iter [50/209], Loss: total=0.933, reg=0.083, containing_obj=0.565, no_obj=0.166, cls=0.119
# Epoch [44/50], Iter [100/209], Loss: total=0.930, reg=0.080, containing_obj=0.567, no_obj=0.166, cls=0.117
# Epoch [44/50], Iter [150/209], Loss: total=0.927, reg=0.079, containing_obj=0.564, no_obj=0.165, cls=0.118
# Epoch [44/50], Iter [200/209], Loss: total=0.918, reg=0.078, containing_obj=0.562, no_obj=0.166, cls=0.112
#
#
# Starting epoch 45 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [45/50], Iter [50/209], Loss: total=0.930, reg=0.081, containing_obj=0.566, no_obj=0.163, cls=0.120
# Epoch [45/50], Iter [100/209], Loss: total=0.920, reg=0.079, containing_obj=0.566, no_obj=0.164, cls=0.112
# Epoch [45/50], Iter [150/209], Loss: total=0.922, reg=0.078, containing_obj=0.566, no_obj=0.165, cls=0.113
# Epoch [45/50], Iter [200/209], Loss: total=0.916, reg=0.078, containing_obj=0.561, no_obj=0.165, cls=0.112
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████████| 4950/4950 [04:56<00:00, 16.68it/s]
# ---class aeroplane ap 0.4010680141968908---
# ---class bicycle ap 0.5352807114670718---
# ---class bird ap 0.4128313753279085---
# ---class boat ap 0.21268792568372488---
# ---class bottle ap 0.15397171340513666---
# ---class bus ap 0.5094258447237363---
# ---class car ap 0.5682273020262467---
# ---class cat ap 0.6640722954733677---
# ---class chair ap 0.29108190707173276---
# ---class cow ap 0.4840763519680744---
# ---class diningtable ap 0.2731559322688139---
# ---class dog ap 0.6422910307613162---
# ---class horse ap 0.6546952670916167---
# ---class motorbike ap 0.49561648800034097---
# ---class person ap 0.5027616680940983---
# ---class pottedplant ap 0.13691052119668015---
# ---class sheep ap 0.4126395215698623---
# ---class sofa ap 0.3908125573200773---
# ---class train ap 0.5344035490778188---
# ---class tvmonitor ap 0.4249300701214508---
# ---map 0.4350470023422983---
# 44 [0.4010680141968908, 0.5352807114670718, 0.4128313753279085, 0.21268792568372488, 0.15397171340513666, 0.5094258447237363, 0.5682273020262467, 0.6640722954733677, 0.29108190707173276, 0.4840763519680744, 0.2731559322688139, 0.6422910307613162, 0.6546952670916167, 0.49561648800034097, 0.5027616680940983, 0.13691052119668015, 0.4126395215698623, 0.3908125573200773, 0.5344035490778188, 0.4249300701214508]
#
#
# Starting epoch 46 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [46/50], Iter [50/209], Loss: total=0.903, reg=0.075, containing_obj=0.552, no_obj=0.171, cls=0.105
# Epoch [46/50], Iter [100/209], Loss: total=0.910, reg=0.075, containing_obj=0.558, no_obj=0.168, cls=0.108
# Epoch [46/50], Iter [150/209], Loss: total=0.920, reg=0.077, containing_obj=0.565, no_obj=0.167, cls=0.111
# Epoch [46/50], Iter [200/209], Loss: total=0.925, reg=0.078, containing_obj=0.566, no_obj=0.167, cls=0.114
#
#
# Starting epoch 47 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [47/50], Iter [50/209], Loss: total=0.928, reg=0.076, containing_obj=0.565, no_obj=0.170, cls=0.117
# Epoch [47/50], Iter [100/209], Loss: total=0.920, reg=0.076, containing_obj=0.566, no_obj=0.169, cls=0.110
# Epoch [47/50], Iter [150/209], Loss: total=0.924, reg=0.077, containing_obj=0.563, no_obj=0.167, cls=0.117
# Epoch [47/50], Iter [200/209], Loss: total=0.934, reg=0.077, containing_obj=0.571, no_obj=0.166, cls=0.120
#
#
# Starting epoch 48 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [48/50], Iter [50/209], Loss: total=0.928, reg=0.079, containing_obj=0.563, no_obj=0.168, cls=0.118
# Epoch [48/50], Iter [100/209], Loss: total=0.919, reg=0.079, containing_obj=0.562, no_obj=0.166, cls=0.113
# Epoch [48/50], Iter [150/209], Loss: total=0.911, reg=0.078, containing_obj=0.554, no_obj=0.166, cls=0.112
# Epoch [48/50], Iter [200/209], Loss: total=0.916, reg=0.079, containing_obj=0.559, no_obj=0.167, cls=0.112
#
#
# Starting epoch 49 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [49/50], Iter [50/209], Loss: total=0.932, reg=0.080, containing_obj=0.564, no_obj=0.169, cls=0.117
# Epoch [49/50], Iter [100/209], Loss: total=0.926, reg=0.078, containing_obj=0.564, no_obj=0.168, cls=0.116
# Epoch [49/50], Iter [150/209], Loss: total=0.921, reg=0.078, containing_obj=0.559, no_obj=0.169, cls=0.114
# Epoch [49/50], Iter [200/209], Loss: total=0.923, reg=0.078, containing_obj=0.562, no_obj=0.168, cls=0.115
#
#
# Starting epoch 50 / 50
# Learning Rate for this epoch: 1e-05
# Epoch [50/50], Iter [50/209], Loss: total=0.933, reg=0.079, containing_obj=0.579, no_obj=0.162, cls=0.113
# Epoch [50/50], Iter [100/209], Loss: total=0.943, reg=0.079, containing_obj=0.578, no_obj=0.166, cls=0.120
# Epoch [50/50], Iter [150/209], Loss: total=0.931, reg=0.077, containing_obj=0.570, no_obj=0.167, cls=0.117
# Epoch [50/50], Iter [200/209], Loss: total=0.919, reg=0.077, containing_obj=0.566, no_obj=0.166, cls=0.110
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████████| 4950/4950 [04:53<00:00, 16.86it/s]
# ---class aeroplane ap 0.41898268204134836---
# ---class bicycle ap 0.5312058757554363---
# ---class bird ap 0.4044105459620767---
# ---class boat ap 0.21148832292734626---
# ---class bottle ap 0.15312456842189887---
# ---class bus ap 0.5428663066715351---
# ---class car ap 0.5850070261296993---
# ---class cat ap 0.6695354745000114---
# ---class chair ap 0.28071355643665696---
# ---class cow ap 0.48852292523394747---
# ---class diningtable ap 0.28166902629179985---
# ---class dog ap 0.6544899852729749---
# ---class horse ap 0.6353182414784873---
# ---class motorbike ap 0.5208118627331441---
# ---class person ap 0.5045412672131862---
# ---class pottedplant ap 0.16088847699672715---
# ---class sheep ap 0.4169567567609397---
# ---class sofa ap 0.40122079260189575---
# ---class train ap 0.5650421008274267---
# ---class tvmonitor ap 0.45362020920366775---
# ---map 0.4440208001730103---
# 49 [0.41898268204134836, 0.5312058757554363, 0.4044105459620767, 0.21148832292734626, 0.15312456842189887, 0.5428663066715351, 0.5850070261296993, 0.6695354745000114, 0.28071355643665696, 0.48852292523394747, 0.28166902629179985, 0.6544899852729749, 0.6353182414784873, 0.5208118627331441, 0.5045412672131862, 0.16088847699672715, 0.4169567567609397, 0.40122079260189575, 0.5650421008274267, 0.45362020920366775]

# %% [markdown]
# # View example predictions

# %%
net.eval()

# select random image from test set
image_name = random.choice(test_dataset.fnames)
image = cv2.imread(os.path.join(file_root_test, image_name))
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

print('predicting...')
result = predict_image(net, image_name, root_img_directory=file_root_test)
for left_up, right_bottom, class_name, _, prob in result:
    color = COLORS[VOC_CLASSES.index(class_name)]
    cv2.rectangle(image, left_up, right_bottom, color, 2)
    label = class_name + str(round(prob, 2))
    text_size, baseline = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.4, 1)
    p1 = (left_up[0], left_up[1] - text_size[1])
    cv2.rectangle(image, (p1[0] - 2 // 2, p1[1] - 2 - baseline), (p1[0] + text_size[0], p1[1] + text_size[1]),
                  color, -1)
    cv2.putText(image, label, (p1[0], p1[1] + baseline), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (255, 255, 255), 1, 8)

plt.figure(figsize = (15,15))
plt.imshow(image)
# Out:
# predicting...

# %% [markdown]
# ## Evaluate on Test
#
# To evaluate detection results we use mAP (mean of average precision over each class)

# %%
test_aps = evaluate(net, test_dataset_file=annotation_file_test, img_root=file_root_test)
# Out:
# ---Evaluate model on test samples---
# 100%|██████████████████████████████████████████████████████████████████████████| 4950/4950 [04:52<00:00, 16.93it/s]
# ---class aeroplane ap 0.41898268204134836---
# ---class bicycle ap 0.5312058757554363---
# ---class bird ap 0.4044105459620767---
# ---class boat ap 0.21148832292734626---
# ---class bottle ap 0.15312456842189887---
# ---class bus ap 0.5428663066715351---
# ---class car ap 0.5850070261296993---
# ---class cat ap 0.6695354745000114---
# ---class chair ap 0.28071355643665696---
# ---class cow ap 0.48852292523394747---
# ---class diningtable ap 0.28166902629179985---
# ---class dog ap 0.6544899852729749---
# ---class horse ap 0.6353182414784873---
# ---class motorbike ap 0.5208118627331441---
# ---class person ap 0.5045412672131862---
# ---class pottedplant ap 0.16088847699672715---
# ---class sheep ap 0.4169567567609397---
# ---class sofa ap 0.40122079260189575---
# ---class train ap 0.5650421008274267---
# ---class tvmonitor ap 0.45362020920366775---
# ---map 0.4440208001730103---
